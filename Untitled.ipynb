# %%
from dask_jobqueue import SLURMCluster
from dask.distributed import Client, LocalCluster
# cluster = SLURMCluster(
#     cores=16,
#     processes=8,
#     memory="128GB",
#     account="nldmlam",
#     walltime="00:20:00",
#     job_script_prologue=[
#         'export LANG="en_US.utf8"',
#         'export LANGUAGE="en_US.utf8"',
#         'export LC_ALL="en_US.utf8"',
#     ],
#     job_extra_directives=['--qos="nf"'],
# )
cluster = LocalCluster()

# %%
client = Client(cluster)

# %%
cluster
# Out:
# LocalCluster(9fc0b43f, 'tcp://127.0.0.1:44427', workers=2, threads=2, memory=8.00 GiB)

# %%
from main import *
# dask.config.set(scheduler="synchronous")
import yaml
import logging
import os
# from dask.distributed import Client
# client = Client('tcp://127.0.0.1:44897')
# from dask.distributed import Client
# client = Client(processes=False)  # Starts local cluster
os.environ['HDF5_USE_FILE_LOCKING']='FALSE'

# %%
setup_logging("logging.yaml")

#args = parser.parse_args()
#casefile = args.casefile
# logging.basicConfig(level=logging.INFO)
# args = parser.parse_args()
# casefile = args.casefile
# casefile = "my_own_cases/mini_open.yaml"
# casefile = "my_own_cases/mini_in_mini_open.yaml"
casefile = "my_own_cases/in_harm.yaml"
# logger.info("Processing casefile %s", casefile)
with open("machine_conf.yaml", "r") as file:
    machine_conf = yaml.safe_load(file)
with open(casefile, "r") as f:
    config = yaml.safe_load(f)
case = DalesCase(config, machine_conf=machine_conf)
case.setup_writers()
case.default_from_yaml()
# Out:
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Entering __init__
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Exiting __init__
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.Emission.create_emis | Entering setup_emissions
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.Emission.create_emis | Entering __init__
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.Emission.create_emis | Exiting __init__
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.Emission.create_emis | Exiting setup_emissions
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LBC.openboundary | Entering do_openboundary
# 2026-01-19 12:55:06 | WARNING  | helper_scripts.LBC.openboundary | Passing wrong grid type to openboundary, converting to GridDalesOpenBC with as_openBC.
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LBC.openboundary | Exiting do_openboundary
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Entering init_lutypes_ifs
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Entering calc_totcover
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Exiting calc_totcover
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Entering calc_totcover
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Exiting calc_totcover
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Entering calc_totcover
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Exiting calc_totcover
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Entering calc_totcover
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Exiting calc_totcover
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Exiting init_lutypes_ifs
# 2026-01-19 12:55:06 | WARNING  | main | Emission is not setting up job properly!!
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.Emission.create_emis | Entering write_emissions_constant
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.Emission.create_emis | Exiting write_emissions_constant

# %%
case.prepare_calculations()
# Out:
# 2026-01-19 12:55:06 | DEBUG    | helper_scripts.LBC.prep_harmonie | Entering create_xarray_dataset
# 2026-01-19 12:55:06 | DEBUG    | gribapi.bindings | eccodes lib search: trying to find binary wheel
# 2026-01-19 12:55:06 | DEBUG    | gribapi.bindings | eccodes lib search: looking in /lus/h2resw01/hpcperm/nld4411/venvs/myvenv/lib/python3.12/site-packages/eccodes.libs
# 2026-01-19 12:55:06 | DEBUG    | gribapi.bindings | eccodes lib search: returning wheel library from /lus/h2resw01/hpcperm/nld4411/venvs/myvenv/lib/python3.12/site-packages/eccodes.libs/libeccodes-f2422c9f.so
# 2026-01-19 12:55:06 | DEBUG    | gribapi.bindings | eccodes lib search: versions: {'eccodes': '2.38.1'}
# 2026-01-19 12:55:07 | DEBUG    | fiona.env | GDAL data files are available at built-in paths.
# 2026-01-19 12:55:07 | DEBUG    | fiona.env | PROJ data files are available at built-in paths.
# 2026-01-19 12:55:07 | DEBUG    | fiona._env | GDAL data files are available at built-in paths.
# 2026-01-19 12:55:07 | DEBUG    | fiona._env | PROJ data files are available at built-in paths.
# 2026-01-19 12:55:07 | DEBUG    | rasterio.env | GDAL data files are available at built-in paths.
# 2026-01-19 12:55:07 | DEBUG    | rasterio.env | PROJ data files are available at built-in paths.
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Entering get_transform_time
# 2026-01-19 12:55:08 | DEBUG    | pyproj | PROJ_ERROR: proj_create: several objects matching this name: Krovak (Greenwich), Equal Earth Greenwich, Laborde Grid (Greenwich), Modified Krovak (Greenwich), Krovak East North (Greenwich), Modified Krovak East North (Greenwich), ...
# /etc/ecmwf/nfs/dh1_home_b/nld4411/DALES_test_input_generator/helper_scripts/LBC/prep_harmonie.py:488: UserWarning: Variable(s) referenced in formula_terms not in variables: ['aps']
#   ds_ml = xr.open_dataset(
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Exiting get_transform_time
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Succesfully read in HARMONIE_ml_glob
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Interpolating sfc time dimension to ml time dimension
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Succesfully read in and interpolated HARMONIE_sfc_glob
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Succesfully read in vars, merging now... also saving to netcdf
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Reading in saved dataset
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Read in saved dataset
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Exiting create_xarray_dataset
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Entering update_transform
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Skipping transform update, we are keeping the original transform.
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Exiting update_transform
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Entering prep_harmonie
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Entering calculate_pressure
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Exiting calculate_pressure
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Entering merge_steps
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Exiting merge_steps
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Entering calculate_3d_height_levels
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Exiting calculate_3d_height_levels
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Entering get_ref_height_crop
# 2026-01-19 12:55:08 | DEBUG    | helper_scripts.LBC.prep_harmonie | Exiting get_ref_height_crop
# <xarray.DataArray 'z3d' (lev: 21)> Size: 168B
# array([864.98518251, 792.62049632, 723.5258143 , 657.63621213,
#        594.8711878 , 535.13456276, 478.31446956, 424.28330416,
#        373.01098243, 324.57229605, 279.04192002, 236.49438835,
#        197.0040686 , 160.64515315, 127.49166601,  97.61745253,
#         71.09615491,  48.00116931,  28.4055382 ,  12.38152762,
#          0.        ])
# Coordinates:
#   * lev      (lev) int64 168B 70 71 72 73 74 75 76 77 ... 84 85 86 87 88 89 90
# 2026-01-19 12:55:16 | DEBUG    | helper_scripts.LBC.prep_harmonie | Entering interpolate_ref_height
# 2026-01-19 12:55:16 | DEBUG    | helper_scripts.LBC.prep_harmonie | Checking if data is ascending..
# 2026-01-19 12:55:16 | DEBUG    | helper_scripts.LBC.prep_harmonie | Checking if data is ascending.. SUCCEEDED
# 2026-01-19 12:55:16 | DEBUG    | helper_scripts.LBC.prep_harmonie | Successfully inverted data!
# 2026-01-19 12:55:16 | DEBUG    | helper_scripts.LBC.prep_harmonie | Entering vertical_interp_all
# 2026-01-19 12:55:16 | DEBUG    | helper_scripts.LBC.prep_harmonie | Exiting vertical_interp_all
# 2026-01-19 12:55:16 | DEBUG    | helper_scripts.LBC.prep_harmonie | Exiting interpolate_ref_height
# 2026-01-19 12:55:16 | DEBUG    | helper_scripts.LBC.prep_harmonie | Entering calc_base_exner
# 2026-01-19 12:55:16 | DEBUG    | helper_scripts.LBC.prep_harmonie | Calculating profile means
# 2026-01-19 12:55:16 | DEBUG    | helper_scripts.LBC.prep_harmonie | Calculating surface temperature
# 2026-01-19 12:55:59 | DEBUG    | helper_scripts.LBC.prep_harmonie | Calculating surface pressure
# 2026-01-19 12:55:59 | DEBUG    | helper_scripts.LBC.helper | Entering calcBaseprof
# 2026-01-19 12:55:59 | DEBUG    | helper_scripts.LBC.helper | Exiting calcBaseprof
# 2026-01-19 12:55:59 | DEBUG    | helper_scripts.LBC.prep_harmonie | Exiting calc_base_exner
# 2026-01-19 12:55:59 | DEBUG    | helper_scripts.LBC.prep_harmonie | Getting surface pressure and temperature
# 2026-01-19 12:55:59 | DEBUG    | helper_scripts.LBC.prep_harmonie | Creating exnr dataarray
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.prep_harmonie | Assigning exnr dataarray
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.prep_harmonie | Calculating liquid potential temperature
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.prep_harmonie | Assigning liquid potential temperature
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.prep_harmonie | Calculating synthetic turbulence parameters
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.prep_harmonie | Organizing data, renaming variables, dropping non-DALES variables and setting transform
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.prep_harmonie | Optimizing data
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.prep_harmonie | Exiting prep_harmonie
# 2026-01-19 12:56:00 | INFO     | helper_scripts.LBC.openboundary | Setting namelist NAMSURFACE:ps to 102124.194224
# 2026-01-19 12:56:00 | INFO     | helper_scripts.LBC.openboundary | Setting namelist NAMSURFACE:thls to 299.779054
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.openboundary | Setting up boundary fields
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.boundary | Entering boundary_fields
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.boundary | Entering get_boundaries
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {'x', Ellipsis} do not exist. Expected one or more of ('time', 'y', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {'x', Ellipsis} do not exist. Expected one or more of ('time', 'y', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {'x', Ellipsis} do not exist. Expected one or more of ('time', 'y', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {'x', Ellipsis} do not exist. Expected one or more of ('time', 'y', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {'x', Ellipsis} do not exist. Expected one or more of ('time', 'y', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {'x', Ellipsis} do not exist. Expected one or more of ('time', 'y', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {'x', Ellipsis} do not exist. Expected one or more of ('time', 'y', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {'x', Ellipsis} do not exist. Expected one or more of ('time', 'y', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {'x', Ellipsis} do not exist. Expected one or more of ('time', 'y', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {'x', Ellipsis} do not exist. Expected one or more of ('time', 'y', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'y'} do not exist. Expected one or more of ('time', 'x', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'y'} do not exist. Expected one or more of ('time', 'x', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'y'} do not exist. Expected one or more of ('time', 'x', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'y'} do not exist. Expected one or more of ('time', 'x', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'y'} do not exist. Expected one or more of ('time', 'x', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'y'} do not exist. Expected one or more of ('time', 'x', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'y'} do not exist. Expected one or more of ('time', 'x', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'y'} do not exist. Expected one or more of ('time', 'x', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'y'} do not exist. Expected one or more of ('time', 'x', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.boundary | Exiting get_boundaries
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.boundary | Entering set_time_attrs
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.boundary | Exiting set_time_attrs
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.boundary | Entering set_variable_attributes
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.boundary | Exiting set_variable_attributes
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.boundary | Exiting boundary_fields
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.openboundary | Setting up initial fields
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.initfields | Entering initial_fields
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.initfields | Entering add_units_and_names
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.initfields | Exiting add_units_and_names
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.initfields | Exiting initial_fields
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.openboundary | Setup all openBC fields, optimizing fields now..
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'y'} do not exist. Expected one or more of ('time', 'x', 'z')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'z'} do not exist. Expected one or more of ('time', 'y', 'x')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'z'} do not exist. Expected one or more of ('time', 'y', 'x')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'z'} do not exist. Expected one or more of ('time', 'y', 'x')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'z'} do not exist. Expected one or more of ('time', 'y', 'x')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis, 'z'} do not exist. Expected one or more of ('time', 'y', 'x')
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# /usr/local/apps/python3/3.12.11-01/lib/python3.12/site-packages/xarray/namedarray/utils.py:164: UserWarning: Dimensions {Ellipsis} do not exist. Expected one or more of FrozenMappingWarningOnValuesAccess({'x': 131, 'y': 131, 'z': 21, 'dim_0': 0})
#   existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
# 2026-01-19 12:56:00 | DEBUG    | helper_scripts.LBC.openboundary | Optimized fields

# %%
case.write_files()
# Out:
# 2026-01-19 12:56:03 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Entering save_netcdf
# 2026-01-19 12:56:04 | DEBUG    | helper_scripts.LSM.LSM_output_dales | Exiting save_netcdf
# 2026-01-19 12:56:04 | DEBUG    | helper_scripts.LBC.openboundary | Optimizing initial fields
# 2026-01-19 12:56:05 | DEBUG    | helper_scripts.LBC.openboundary | Writing initial fields
# 2026-01-19 12:57:03 | DEBUG    | helper_scripts.LBC.openboundary | Optimizing boundaries
# 2026-01-19 12:57:04 | DEBUG    | helper_scripts.LBC.openboundary | Writing boundaries
# 2026-01-19 13:07:04 | INFO     | main | Writing job file to /ec/res4/scratch/nld4411/dales_cases/2_HARMONIE_test/job.001
# 2026-01-19 13:07:05 | INFO     | main | Written input files to /ec/res4/scratch/nld4411/dales_cases/2_HARMONIE_test/input

# %%
case.openbc_creator.harmonieprepper

# %%
case.openbc_creator.boundaries.compute()

# %%
display.display_html(case.openbc_creator.harmonieprepper.data.u)
case.openbc_creator.harmonieprepper.data.data.visualize("1.png")

# %%
case.openbc_creator.boundaries.ueast.data.visualize("test.pdf")

# %%
grid = case.openbc_creator.grid
north = (case.openbc_creator.harmonieprepper.data.sel(
        y=slice(grid.yt[-1] - grid.dy * 16, grid.yt[-1] + grid.dy * 16),
        x=slice(grid.xt[0] - grid.dx * 16, grid.xt[-1] + grid.dx * 16),
    )
        )

# %%
north["u"].interp(z=grid.zt, y=grid.ym[-1], x=grid.xm, assume_sorted=True)

# %%
north["u"].interp(z=grid.zt).interp(y=grid.ym[-1], x=grid.xm, assume_sorted=True)
# Out:
# <xarray.DataArray 'u' (time: 698, x: 512, z: 40)> Size: 57MB
# dask.array<transpose, shape=(698, 512, 40), dtype=float32, chunksize=(1, 512, 40), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 6kB 2023-08-20T12:00:00 ... 2023-08-20T17:...
#   * x        (x) float64 4kB 3.72e+04 3.725e+04 3.73e+04 ... 6.27e+04 6.275e+04
#   * z        (z) float64 320B 5.0 15.0 25.0 35.0 ... 365.0 375.0 385.0 395.0
#     y        float64 8B 6.275e+04

# %%
dask.config.get("scheduler")
# Out:
# 'dask.distributed'
